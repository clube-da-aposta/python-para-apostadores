# %% [markdown]
# ![alt text](https://trello-attachments.s3.amazonaws.com/56b4dc9a5618cc0446578ec6/5c6ffc4673fc7e8ac0a66708/c5f7d8d143f69ffd6683d6ad5b72c58f/Machine-Learning-e-Ciência-de-dados-nas-apostas-esportivas.png)

# %%
# Importa Bibliotecas
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import json
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
#Setting Pandas to show all columns
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:,.2f}'.format

api_key = '###########################################'

# %% [markdown]
# ## Usando API e processando dados

# %%
requests.get(f'https://apiv2.apifootball.com/?action=get_countries&APIkey={api_key}').json()
# Out:
# [{'country_id': '41', 'country_name': 'England'},
#  {'country_id': '46', 'country_name': 'France'}]

# %%
requests.get(f'https://apiv2.apifootball.com/?action=get_leagues&country_id=41&APIkey={api_key}').json()
# Out:
# [{'country_id': '41',
#   'country_name': 'England',
#   'league_id': '149',
#   'league_name': 'Championship',
#   'league_season': '2019/2020'}]

# %%
requests.get(f'https://apiv2.apifootball.com/?action=get_leagues&country_id=46&APIkey={api_key}').json()
# Out:
# [{'country_id': '46',
#   'country_name': 'France',
#   'league_id': '177',
#   'league_name': 'Ligue 2',
#   'league_season': '2019/2020'}]

# %%
matches = requests.get(f'https://apiv2.apifootball.com/?action=get_events&from=2015-08-01&to=2019-05-05&league_id=149&APIkey={api_key}').json()

# %%
matches[0]
# Out:
# {'match_id': '13537',
#  'country_id': '41',
#  'country_name': 'England',
#  'league_id': '149',
#  'league_name': 'Championship',
#  'match_date': '2017-08-04',
#  'match_status': 'Finished',
#  'match_time': '20:45',
#  'match_hometeam_id': '2634',
#  'match_hometeam_name': 'Nottingham',
#  'match_hometeam_score': '1',
#  'match_awayteam_name': 'Millwall',
#  'match_awayteam_id': '2638',
#  'match_awayteam_score': '0',
#  'match_hometeam_halftime_score': '1',
#  'match_awayteam_halftime_score': '0',
#  'match_hometeam_extra_score': '',
#  'match_awayteam_extra_score': '',
#  'match_hometeam_penalty_score': '',
#  'match_awayteam_penalty_score': '',
#  'match_hometeam_ft_score': '',
#  'match_awayteam_ft_score': '',
#  'match_hometeam_system': '4 - 1 - 4 - 1',
#  'match_awayteam_system': '4 - 4 - 2',
#  'match_live': '0',
#  'match_round': 'Round 1',
#  'match_stadium': '',
#  'match_referee': '',
#  'goalscorer': [{'time': '41',
#    'home_scorer': 'McKay B.',
#    'score': '1 - 0',
#    'away_scorer': '',
#    'info': ''}],
#  'cards': [{'time': '89',
#    'home_fault': '',
#    'card': 'yellow card',
#    'away_fault': ' Saville G.',
#    'info': ''}],
#  'substitutions': {'home': [{'time': '59',
#     'substitution': ' Osborn B. | Cohen C.'},
#    {'time': '59', 'substitution': ' Brereton B. | Dowell K.'},
#    {'time': '77', 'substitution': ' Murphy D. | Mills M.'}],
#   'away': [{'time': '67', 'substitution': "O'Brien A.  | Onyedinma F."},
#    {'time': '78', 'substitution': 'Gregory L.  | Ferguson S.'},
#    {'time': '83', 'substitution': 'Williams S.  | Elliott T.'}]},
#  'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Brereton B.',
#      'lineup_number': '17',
#      'lineup_position': '7'},
#     {'lineup_player': 'Clough Z.',
#      'lineup_number': '16',
#      'lineup_position': '8'},
#     {'lineup_player': 'Darikwa T.',
#      'lineup_number': '27',
#      'lineup_position': '2'},
#     {'lineup_player': 'Mancienne M. (C)',
#      'lineup_number': '4',
#      'lineup_position': '4'},
#     {'lineup_player': 'McKay B.',
#      'lineup_number': '10',
#      'lineup_position': '10'},
#     {'lineup_player': 'Murphy D.',
#      'lineup_number': '9',
#      'lineup_position': '11'},
#     {'lineup_player': 'Osborn B.',
#      'lineup_number': '11',
#      'lineup_position': '9'},
#     {'lineup_player': 'Smith J. (G)',
#      'lineup_number': '43',
#      'lineup_position': '1'},
#     {'lineup_player': 'Traore A.',
#      'lineup_number': '6',
#      'lineup_position': '5'},
#     {'lineup_player': 'Vaughan D.',
#      'lineup_number': '24',
#      'lineup_position': '6'},
#     {'lineup_player': 'Worrall J.',
#      'lineup_number': '42',
#      'lineup_position': '3'}],
#    'substitutes': [{'lineup_player': 'Cohen C.',
#      'lineup_number': '8',
#      'lineup_position': ''},
#     {'lineup_player': 'Cummings J.',
#      'lineup_number': '35',
#      'lineup_position': ''},
#     {'lineup_player': 'Dowell K.',
#      'lineup_number': '20',
#      'lineup_position': ''},
#     {'lineup_player': 'Evtimov D. (G)',
#      'lineup_number': '26',
#      'lineup_position': ''},
#     {'lineup_player': 'Lichaj E.',
#      'lineup_number': '2',
#      'lineup_position': ''},
#     {'lineup_player': 'Mills M.', 'lineup_number': '5', 'lineup_position': ''},
#     {'lineup_player': 'Vellios A.',
#      'lineup_number': '39',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Warburton M.',
#      'lineup_number': '-1',
#      'lineup_position': ''}],
#    'missing_players': [{'lineup_player': 'Henderson S.',
#      'lineup_number': '-1',
#      'lineup_position': ''},
#     {'lineup_player': 'Ward J.',
#      'lineup_number': '-1',
#      'lineup_position': ''}]},
#   'away': {'starting_lineups': [{'lineup_player': 'Archer J. (G)',
#      'lineup_number': '1',
#      'lineup_position': '1'},
#     {'lineup_player': 'Cooper J.',
#      'lineup_number': '35',
#      'lineup_position': '4'},
#     {'lineup_player': 'Gregory L.',
#      'lineup_number': '9',
#      'lineup_position': '10'},
#     {'lineup_player': 'Hutchinson S.',
#      'lineup_number': '4',
#      'lineup_position': '3'},
#     {'lineup_player': 'McLaughlin C.',
#      'lineup_number': '2',
#      'lineup_position': '2'},
#     {'lineup_player': 'Meredith J.',
#      'lineup_number': '3',
#      'lineup_position': '5'},
#     {'lineup_player': 'Morison S. (C)',
#      'lineup_number': '20',
#      'lineup_position': '11'},
#     {'lineup_player': "O'Brien A.",
#      'lineup_number': '22',
#      'lineup_position': '9'},
#     {'lineup_player': 'Saville G.',
#      'lineup_number': '23',
#      'lineup_position': '8'},
#     {'lineup_player': 'Wallace J.',
#      'lineup_number': '14',
#      'lineup_position': '6'},
#     {'lineup_player': 'Williams S.',
#      'lineup_number': '6',
#      'lineup_position': '7'}],
#    'substitutes': [{'lineup_player': 'Craig T.',
#      'lineup_number': '5',
#      'lineup_position': ''},
#     {'lineup_player': 'Elliott T.',
#      'lineup_number': '-1',
#      'lineup_position': ''},
#     {'lineup_player': 'Ferguson S.',
#      'lineup_number': '18',
#      'lineup_position': ''},
#     {'lineup_player': 'King T. (G)',
#      'lineup_number': '31',
#      'lineup_position': ''},
#     {'lineup_player': 'Onyedinma F.',
#      'lineup_number': '10',
#      'lineup_position': ''},
#     {'lineup_player': 'Thompson B.',
#      'lineup_number': '-1',
#      'lineup_position': ''},
#     {'lineup_player': 'Webster B.',
#      'lineup_number': '17',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Harris N.',
#      'lineup_number': '-1',
#      'lineup_position': ''}],
#    'missing_players': []}},
#  'statistics': [{'type': 'Ball Possession', 'home': '68%', 'away': '32%'},
#   {'type': 'Goal Attempts', 'home': '11', 'away': '23'},
#   {'type': 'Shots on Goal', 'home': '2', 'away': '6'},
#   {'type': 'Shots off Goal', 'home': '5', 'away': '13'},
#   {'type': 'Blocked Shots', 'home': '4', 'away': '4'},
#   {'type': 'Free Kicks', 'home': '18', 'away': '17'},
#   {'type': 'Corner Kicks', 'home': '5', 'away': '4'},
#   {'type': 'Offsides', 'home': '4', 'away': '3'},
#   {'type': 'Goalkeeper Saves', 'home': '6', 'away': '1'},
#   {'type': 'Fouls', 'home': '13', 'away': '15'},
#   {'type': 'Yellow Cards', 'home': '0', 'away': '1'}]}

# %%
matches[0]['statistics']
# Out:
# [{'type': 'Ball Possession', 'home': '68%', 'away': '32%'},
#  {'type': 'Goal Attempts', 'home': '11', 'away': '23'},
#  {'type': 'Shots on Goal', 'home': '2', 'away': '6'},
#  {'type': 'Shots off Goal', 'home': '5', 'away': '13'},
#  {'type': 'Blocked Shots', 'home': '4', 'away': '4'},
#  {'type': 'Free Kicks', 'home': '18', 'away': '17'},
#  {'type': 'Corner Kicks', 'home': '5', 'away': '4'},
#  {'type': 'Offsides', 'home': '4', 'away': '3'},
#  {'type': 'Goalkeeper Saves', 'home': '6', 'away': '1'},
#  {'type': 'Fouls', 'home': '13', 'away': '15'},
#  {'type': 'Yellow Cards', 'home': '0', 'away': '1'}]

# %%
match_list = []
for i in range(len(matches)):
    try:
        match_dict = {'date': matches[i]['match_date'], 'home_team': matches[i]['match_hometeam_name'], 'away_team': matches[i]['match_awayteam_name'],
                      'home_score': int(matches[i]['match_hometeam_score']), 'away_score': int(matches[i]['match_awayteam_score'])} 
    except ValueError:
        continue
    for stat in matches[i]['statistics']:
        match_dict['home_' + '_'.join(stat['type'].split(' ')).lower()] = stat['home']
        match_dict['away_' + '_'.join(stat['type'].split(' ')).lower()] = stat['away']
        
    match_list.append(match_dict)

# %%
df = pd.DataFrame(match_list)

# %%
df.head()
# Out:
#          date     home_team  away_team  home_score  away_score  \
# 0  2017-08-04    Nottingham   Millwall           1           0
# 1  2017-08-04    Sunderland      Derby           1           1
# 2  2017-08-05   Aston Villa  Hull City           1           1
# 3  2017-08-05  Bristol City   Barnsley           3           1
# 4  2017-08-05        Burton    Cardiff           0           1
#
#   home_ball_possession away_ball_possession home_goal_attempts  \
# 0                  68%                  32%                 11
# 1                  46%                  54%                 20
# 2                  51%                  49%                 12
# 3                  58%                  42%                 20
# 4                  53%                  47%                  3
#
#   away_goal_attempts home_shots_on_goal away_shots_on_goal  \
# 0                 23                  2                  6
# 1                 11                  4                  4
# 2                 14                  5                  5
# 3                 10                 11                  5
# 4                 14                  0                  6
#
#   home_shots_off_goal away_shots_off_goal home_blocked_shots  \
# 0                   5                  13                  4
# 1                  11                   5                  5
# 2                   5                   2                  2
# 3                   6                   4                  3
# 4                   1                   2                  2
#
#   away_blocked_shots home_free_kicks away_free_kicks home_corner_kicks  \
# 0                  4              18              17                 5
# 1                  2              11              13                 6
# 2                  7              12              14                 5
# 3                  1              12              16                 3
# 4                  6              17              14                 4
#
#   away_corner_kicks home_offsides away_offsides home_goalkeeper_saves  \
# 0                 4             4             3                     6
# 1                 7             0             1                     3
# 2                 3             3             1                     4
# 3                 2             2             3                     4
# 4                 6             1             1                     5
#
#   away_goalkeeper_saves home_fouls away_fouls home_yellow_cards  \
# 0                     1         13         15                 0
# 1                     3         12         11                 1
# 2                     4         13         11                 2
# 3                     8         13          9                 1
# 4                     0         13         15                 1
#
#   away_yellow_cards home_red_cards away_red_cards  \
# 0                 1            NaN            NaN
# 1                 0            NaN            NaN
# 2                 0            NaN            NaN
# 3                 2            NaN            NaN
# 4                 0            NaN            NaN
#
#   home_distance_covered_(metres) away_distance_covered_(metres) home_attacks  \
# 0                            NaN                            NaN          NaN
# 1                            NaN                            NaN          NaN
# 2                            NaN                            NaN          NaN
# 3                            NaN                            NaN          NaN
# 4                            NaN                            NaN          NaN
#
#   away_attacks home_dangerous_attacks away_dangerous_attacks home_throw-in  \
# 0          NaN                    NaN                    NaN           NaN
# 1          NaN                    NaN                    NaN           NaN
# 2          NaN                    NaN                    NaN           NaN
# 3          NaN                    NaN                    NaN           NaN
# 4          NaN                    NaN                    NaN           NaN
#
#   away_throw-in home_goal_kicks away_goal_kicks home_pass_success_%  \
# 0           NaN             NaN             NaN                 NaN
# 1           NaN             NaN             NaN                 NaN
# 2           NaN             NaN             NaN                 NaN
# 3           NaN             NaN             NaN                 NaN
# 4           NaN             NaN             NaN                 NaN
#
#   away_pass_success_% home_total_passes away_total_passes  \
# 0                 NaN               NaN               NaN
# 1                 NaN               NaN               NaN
# 2                 NaN               NaN               NaN
# 3                 NaN               NaN               NaN
# 4                 NaN               NaN               NaN
#
#   home_completed_passes away_completed_passes home_tackles away_tackles
# 0                   NaN                   NaN          NaN          NaN
# 1                   NaN                   NaN          NaN          NaN
# 2                   NaN                   NaN          NaN          NaN
# 3                   NaN                   NaN          NaN          NaN
# 4                   NaN                   NaN          NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 47 columns):
# date                              1108 non-null object
# home_team                         1108 non-null object
# away_team                         1108 non-null object
# home_score                        1108 non-null int64
# away_score                        1108 non-null int64
# home_ball_possession              1009 non-null object
# away_ball_possession              1009 non-null object
# home_goal_attempts                1009 non-null object
# away_goal_attempts                1009 non-null object
# home_shots_on_goal                1009 non-null object
# away_shots_on_goal                1009 non-null object
# home_shots_off_goal               1009 non-null object
# away_shots_off_goal               1009 non-null object
# home_blocked_shots                1009 non-null object
# away_blocked_shots                1009 non-null object
# home_free_kicks                   778 non-null object
# away_free_kicks                   778 non-null object
# home_corner_kicks                 1009 non-null object
# away_corner_kicks                 1009 non-null object
# home_offsides                     1009 non-null object
# away_offsides                     1009 non-null object
# home_goalkeeper_saves             1009 non-null object
# away_goalkeeper_saves             1009 non-null object
# home_fouls                        1009 non-null object
# away_fouls                        1009 non-null object
# home_yellow_cards                 955 non-null object
# away_yellow_cards                 955 non-null object
# home_red_cards                    129 non-null object
# away_red_cards                    129 non-null object
# home_distance_covered_(metres)    4 non-null object
# away_distance_covered_(metres)    4 non-null object
# home_attacks                      344 non-null object
# away_attacks                      344 non-null object
# home_dangerous_attacks            344 non-null object
# away_dangerous_attacks            344 non-null object
# home_throw-in                     3 non-null object
# away_throw-in                     3 non-null object
# home_goal_kicks                   3 non-null object
# away_goal_kicks                   3 non-null object
# home_pass_success_%               3 non-null object
# away_pass_success_%               3 non-null object
# home_total_passes                 464 non-null object
# away_total_passes                 464 non-null object
# home_completed_passes             464 non-null object
# away_completed_passes             464 non-null object
# home_tackles                      464 non-null object
# away_tackles                      464 non-null object
# dtypes: int64(2), object(45)
# memory usage: 407.0+ KB

# %%
drop_list = ['home_distance_covered_(metres)', 'away_distance_covered_(metres)', 'home_throw-in',
             'away_throw-in', 'home_goal_kicks', 'away_goal_kicks', 'home_pass_success_%', 'away_pass_success_%',
             'home_total_passes', 'away_total_passes', 'home_completed_passes', 'away_completed_passes', 'home_tackles',
             'away_tackles', 'home_attacks', 'away_attacks', 'home_dangerous_attacks', 'away_dangerous_attacks', 'home_free_kicks',
             'away_free_kicks', 'home_red_cards', 'away_red_cards']
df = df.drop(drop_list, axis=1).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 25 columns):
# date                     1108 non-null object
# home_team                1108 non-null object
# away_team                1108 non-null object
# home_score               1108 non-null int64
# away_score               1108 non-null int64
# home_ball_possession     1009 non-null object
# away_ball_possession     1009 non-null object
# home_goal_attempts       1009 non-null object
# away_goal_attempts       1009 non-null object
# home_shots_on_goal       1009 non-null object
# away_shots_on_goal       1009 non-null object
# home_shots_off_goal      1009 non-null object
# away_shots_off_goal      1009 non-null object
# home_blocked_shots       1009 non-null object
# away_blocked_shots       1009 non-null object
# home_corner_kicks        1009 non-null object
# away_corner_kicks        1009 non-null object
# home_offsides            1009 non-null object
# away_offsides            1009 non-null object
# home_goalkeeper_saves    1009 non-null object
# away_goalkeeper_saves    1009 non-null object
# home_fouls               1009 non-null object
# away_fouls               1009 non-null object
# home_yellow_cards        955 non-null object
# away_yellow_cards        955 non-null object
# dtypes: int64(2), object(23)
# memory usage: 216.5+ KB

# %%
df['home_yellow_cards'] = df['home_yellow_cards'].fillna(0)
df['away_yellow_cards'] = df['away_yellow_cards'].fillna(0)

# %%
df.head()
# Out:
#          date     home_team  away_team  home_score  away_score  \
# 0  2017-08-04    Nottingham   Millwall           1           0
# 1  2017-08-04    Sunderland      Derby           1           1
# 2  2017-08-05   Aston Villa  Hull City           1           1
# 3  2017-08-05  Bristol City   Barnsley           3           1
# 4  2017-08-05        Burton    Cardiff           0           1
#
#   home_ball_possession away_ball_possession home_goal_attempts  \
# 0                  68%                  32%                 11
# 1                  46%                  54%                 20
# 2                  51%                  49%                 12
# 3                  58%                  42%                 20
# 4                  53%                  47%                  3
#
#   away_goal_attempts home_shots_on_goal away_shots_on_goal  \
# 0                 23                  2                  6
# 1                 11                  4                  4
# 2                 14                  5                  5
# 3                 10                 11                  5
# 4                 14                  0                  6
#
#   home_shots_off_goal away_shots_off_goal home_blocked_shots  \
# 0                   5                  13                  4
# 1                  11                   5                  5
# 2                   5                   2                  2
# 3                   6                   4                  3
# 4                   1                   2                  2
#
#   away_blocked_shots home_corner_kicks away_corner_kicks home_offsides  \
# 0                  4                 5                 4             4
# 1                  2                 6                 7             0
# 2                  7                 5                 3             3
# 3                  1                 3                 2             2
# 4                  6                 4                 6             1
#
#   away_offsides home_goalkeeper_saves away_goalkeeper_saves home_fouls  \
# 0             3                     6                     1         13
# 1             1                     3                     3         12
# 2             1                     4                     4         13
# 3             3                     4                     8         13
# 4             1                     5                     0         13
#
#   away_fouls home_yellow_cards away_yellow_cards
# 0         15                 0                 1
# 1         11                 1                 0
# 2         11                 2                 0
# 3          9                 1                 2
# 4         15                 1                 0

# %%
df['home_goals_diff'] = df['home_score'] - df['away_score']
df['away_goals_diff'] = df['away_score'] - df['home_score']

# %%
copia = df.copy()

# %%
for team in list(copia['home_team'].unique()):
    for i in range(len(copia[copia['home_team'] == team])):
        aux = copia[copia['home_team'] == team].iloc[i:5+i]['home_goals_diff']
        if len(aux) < 5:
            break
        else:
            soma = aux.sum()
            index = list(aux.index)[-1]
            copia.loc[index, 'home_5goals_diff'] = soma

for team in list(copia['away_team'].unique()):
    for i in range(len(copia[copia['away_team'] == team])):
        aux = copia[copia['away_team'] == team].iloc[i:5+i]['away_goals_diff']
        if len(aux) < 5:
            break
        else:
            soma = aux.sum()
            index = list(aux.index)[-1]
            copia.loc[index, 'away_5goals_diff'] = soma

# %%
for i in range(len(copia[copia['home_team'] == 'Nottingham'])):
    if len(copia[copia['home_team'] == 'Nottingham'].iloc[i:5+i,:]) < 5:
        break
    else:
        print(copia[copia['home_team'] == 'Nottingham'].iloc[i:5+i,:][['home_goals_diff', 'home_5goals_diff']])
# Out:
#      home_goals_diff  home_5goals_diff
# 0                  1               nan
# 43                 1               nan
# 50                -2               nan
# 92                -1               nan
# 115               -2             -3.00
#      home_goals_diff  home_5goals_diff
# 43                 1               nan
# 50                -2               nan
# 92                -1               nan
# 115               -2             -3.00
# 127                1             -3.00
#      home_goals_diff  home_5goals_diff
# 50                -2               nan
# 92                -1               nan
# 115               -2             -3.00
# 127                1             -3.00
# 150                2             -2.00
#      home_goals_diff  home_5goals_diff
# 92                -1               nan
# 115               -2             -3.00
# 127                1             -3.00
# 150                2             -2.00
# 186                4              4.00
#      home_goals_diff  home_5goals_diff
# 115               -2             -3.00
# 127                1             -3.00
# 150                2             -2.00
# 186                4              4.00
# 208                1              6.00
#      home_goals_diff  home_5goals_diff
# 127                1             -3.00
# 150                2             -2.00
# 186                4              4.00
# 208                1              6.00
# 224               -2              6.00
#      home_goals_diff  home_5goals_diff
# 150                2             -2.00
# 186                4              4.00
# 208                1              6.00
# 224               -2              6.00
# 247                1              6.00
#      home_goals_diff  home_5goals_diff
# 186                4              4.00
# 208                1              6.00
# 224               -2              6.00
# 247                1              6.00
# 285               -3              1.00
#      home_goals_diff  home_5goals_diff
# 208                1              6.00
# 224               -2              6.00
# 247                1              6.00
# 285               -3              1.00
# 297               -1             -4.00
#      home_goals_diff  home_5goals_diff
# 224               -2              6.00
# 247                1              6.00
# 285               -3              1.00
# 297               -1             -4.00
# 323               -1             -6.00
#      home_goals_diff  home_5goals_diff
# 247                1              6.00
# 285               -3              1.00
# 297               -1             -4.00
# 323               -1             -6.00
# 345               -3             -7.00
#      home_goals_diff  home_5goals_diff
# 285               -3              1.00
# 297               -1             -4.00
# 323               -1             -6.00
# 345               -3             -7.00
# 368               -2            -10.00
#      home_goals_diff  home_5goals_diff
# 297               -1             -4.00
# 323               -1             -6.00
# 345               -3             -7.00
# 368               -2            -10.00
# 387                0             -7.00
#      home_goals_diff  home_5goals_diff
# 323               -1             -6.00
# 345               -3             -7.00
# 368               -2            -10.00
# 387                0             -7.00
# 413                1             -5.00
#      home_goals_diff  home_5goals_diff
# 345               -3             -7.00
# 368               -2            -10.00
# 387                0             -7.00
# 413                1             -5.00
# 437                0             -4.00
#      home_goals_diff  home_5goals_diff
# 368               -2            -10.00
# 387                0             -7.00
# 413                1             -5.00
# 437                0             -4.00
# 495               -1             -2.00
#      home_goals_diff  home_5goals_diff
# 387                0             -7.00
# 413                1             -5.00
# 437                0             -4.00
# 495               -1             -2.00
# 509                1              1.00
#      home_goals_diff  home_5goals_diff
# 413                1             -5.00
# 437                0             -4.00
# 495               -1             -2.00
# 509                1              1.00
# 526                3              4.00
#      home_goals_diff  home_5goals_diff
# 437                0             -4.00
# 495               -1             -2.00
# 509                1              1.00
# 526                3              4.00
# 534                0              3.00
#      home_goals_diff  home_5goals_diff
# 495               -1             -2.00
# 509                1              1.00
# 526                3              4.00
# 534                0              3.00
# 570                0              3.00
#      home_goals_diff  home_5goals_diff
# 509                1              1.00
# 526                3              4.00
# 534                0              3.00
# 570                0              3.00
# 576                1              5.00
#      home_goals_diff  home_5goals_diff
# 526                3              4.00
# 534                0              3.00
# 570                0              3.00
# 576                1              5.00
# 614                0              4.00
#      home_goals_diff  home_5goals_diff
# 534                0              3.00
# 570                0              3.00
# 576                1              5.00
# 614                0              4.00
# 648                1              2.00
#      home_goals_diff  home_5goals_diff
# 570                0              3.00
# 576                1              5.00
# 614                0              4.00
# 648                1              2.00
# 658                1              3.00
#      home_goals_diff  home_5goals_diff
# 576                1              5.00
# 614                0              4.00
# 648                1              2.00
# 658                1              3.00
# 685                0              3.00
#      home_goals_diff  home_5goals_diff
# 614                0              4.00
# 648                1              2.00
# 658                1              3.00
# 685                0              3.00
# 706               -1              1.00
#      home_goals_diff  home_5goals_diff
# 648                1              2.00
# 658                1              3.00
# 685                0              3.00
# 706               -1              1.00
# 742                1              2.00
#      home_goals_diff  home_5goals_diff
# 658                1              3.00
# 685                0              3.00
# 706               -1              1.00
# 742                1              2.00
# 756                0              1.00
#      home_goals_diff  home_5goals_diff
# 685                0              3.00
# 706               -1              1.00
# 742                1              2.00
# 756                0              1.00
# 790                2              2.00
#      home_goals_diff  home_5goals_diff
# 706               -1              1.00
# 742                1              2.00
# 756                0              1.00
# 790                2              2.00
# 803               -1              1.00
#      home_goals_diff  home_5goals_diff
# 742                1              2.00
# 756                0              1.00
# 790                2              2.00
# 803               -1              1.00
# 824               -1              1.00
#      home_goals_diff  home_5goals_diff
# 756                0              1.00
# 790                2              2.00
# 803               -1              1.00
# 824               -1              1.00
# 862                2              2.00
#      home_goals_diff  home_5goals_diff
# 790                2              2.00
# 803               -1              1.00
# 824               -1              1.00
# 862                2              2.00
# 885               -1              1.00
#      home_goals_diff  home_5goals_diff
# 803               -1              1.00
# 824               -1              1.00
# 862                2              2.00
# 885               -1              1.00
# 895                2              1.00
#      home_goals_diff  home_5goals_diff
# 824               -1              1.00
# 862                2              2.00
# 885               -1              1.00
# 895                2              1.00
# 917                1              3.00
#      home_goals_diff  home_5goals_diff
# 862                2              2.00
# 885               -1              1.00
# 895                2              1.00
# 917                1              3.00
# 956                1              5.00
#      home_goals_diff  home_5goals_diff
# 885               -1              1.00
# 895                2              1.00
# 917                1              3.00
# 956                1              5.00
# 981                3              6.00
#      home_goals_diff  home_5goals_diff
# 895                2              1.00
# 917                1              3.00
# 956                1              5.00
# 981                3              6.00
# 995               -2              5.00
#       home_goals_diff  home_5goals_diff
# 917                 1              3.00
# 956                 1              5.00
# 981                 3              6.00
# 995                -2              5.00
# 1013                1              4.00
#       home_goals_diff  home_5goals_diff
# 956                 1              5.00
# 981                 3              6.00
# 995                -2              5.00
# 1013                1              4.00
# 1050               -1              2.00
#       home_goals_diff  home_5goals_diff
# 981                 3              6.00
# 995                -2              5.00
# 1013                1              4.00
# 1050               -1              2.00
# 1075                3              4.00
#       home_goals_diff  home_5goals_diff
# 995                -2              5.00
# 1013                1              4.00
# 1050               -1              2.00
# 1075                3              4.00
# 1102                1              2.00

# %%
copia[copia['away_team'] == 'Nottingham'].tail()
# Out:
#             date      home_team   away_team  home_score  away_score  \
# 1002  2019-03-16        Ipswich  Nottingham           1           1
# 1031  2019-04-06      Rotherham  Nottingham           2           1
# 1037  2019-04-09  Sheffield Wed  Nottingham           3           0
# 1059  2019-04-19  Sheffield Utd  Nottingham           2           0
# 1088  2019-04-27            QPR  Nottingham           0           1
#
#      home_ball_possession away_ball_possession home_goal_attempts  \
# 1002                  49%                  51%                 16
# 1031                  47%                  53%                 17
# 1037                  54%                  46%                 14
# 1059                  63%                  37%                 14
# 1088                  55%                  45%                 21
#
#      away_goal_attempts home_shots_on_goal away_shots_on_goal  \
# 1002                 12                  6                  5
# 1031                 13                  5                  4
# 1037                 14                  5                  6
# 1059                  9                  4                  1
# 1088                  7                  7                  4
#
#      home_shots_off_goal away_shots_off_goal home_blocked_shots  \
# 1002                   7                   2                  3
# 1031                   7                   4                  5
# 1037                   5                   4                  4
# 1059                   8                   4                  2
# 1088                  12                   2                  2
#
#      away_blocked_shots home_corner_kicks away_corner_kicks home_offsides  \
# 1002                  5                 6                 5             4
# 1031                  5                 4                 4             1
# 1037                  4                 1                 2             1
# 1059                  4                 9                 2             1
# 1088                  1                 8                 4             0
#
#      away_offsides home_goalkeeper_saves away_goalkeeper_saves home_fouls  \
# 1002             2                     4                     5         16
# 1031             4                     3                     3         10
# 1037             2                     6                     2         14
# 1059             1                     1                     2         16
# 1088             4                     3                     7         11
#
#      away_fouls home_yellow_cards away_yellow_cards  home_goals_diff  \
# 1002         12                 0                 2                0
# 1031         14                 0                 1                1
# 1037         15                 2                 2                3
# 1059          8                 3                 2                2
# 1088         15                 1                 2               -1
#
#       away_goals_diff  home_5goals_diff  away_5goals_diff
# 1002                0             -2.00             -4.00
# 1031               -1              1.00             -3.00
# 1037               -3              5.00             -6.00
# 1059               -2              5.00             -8.00
# 1088                1              0.00             -5.00

# %%
copia.reset_index(inplace=True, drop=True)

# %%
copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 29 columns):
# date                     1108 non-null object
# home_team                1108 non-null object
# away_team                1108 non-null object
# home_score               1108 non-null int64
# away_score               1108 non-null int64
# home_ball_possession     1009 non-null object
# away_ball_possession     1009 non-null object
# home_goal_attempts       1009 non-null object
# away_goal_attempts       1009 non-null object
# home_shots_on_goal       1009 non-null object
# away_shots_on_goal       1009 non-null object
# home_shots_off_goal      1009 non-null object
# away_shots_off_goal      1009 non-null object
# home_blocked_shots       1009 non-null object
# away_blocked_shots       1009 non-null object
# home_corner_kicks        1009 non-null object
# away_corner_kicks        1009 non-null object
# home_offsides            1009 non-null object
# away_offsides            1009 non-null object
# home_goalkeeper_saves    1009 non-null object
# away_goalkeeper_saves    1009 non-null object
# home_fouls               1009 non-null object
# away_fouls               1009 non-null object
# home_yellow_cards        1108 non-null object
# away_yellow_cards        1108 non-null object
# home_goals_diff          1108 non-null int64
# away_goals_diff          1108 non-null int64
# home_5goals_diff         984 non-null float64
# away_5goals_diff         984 non-null float64
# dtypes: float64(2), int64(4), object(23)
# memory usage: 251.2+ KB

# %%
copia.dropna(inplace=True)

# %%
copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 871 entries, 94 to 1107
# Data columns (total 29 columns):
# date                     871 non-null object
# home_team                871 non-null object
# away_team                871 non-null object
# home_score               871 non-null int64
# away_score               871 non-null int64
# home_ball_possession     871 non-null object
# away_ball_possession     871 non-null object
# home_goal_attempts       871 non-null object
# away_goal_attempts       871 non-null object
# home_shots_on_goal       871 non-null object
# away_shots_on_goal       871 non-null object
# home_shots_off_goal      871 non-null object
# away_shots_off_goal      871 non-null object
# home_blocked_shots       871 non-null object
# away_blocked_shots       871 non-null object
# home_corner_kicks        871 non-null object
# away_corner_kicks        871 non-null object
# home_offsides            871 non-null object
# away_offsides            871 non-null object
# home_goalkeeper_saves    871 non-null object
# away_goalkeeper_saves    871 non-null object
# home_fouls               871 non-null object
# away_fouls               871 non-null object
# home_yellow_cards        871 non-null object
# away_yellow_cards        871 non-null object
# home_goals_diff          871 non-null int64
# away_goals_diff          871 non-null int64
# home_5goals_diff         871 non-null float64
# away_5goals_diff         871 non-null float64
# dtypes: float64(2), int64(4), object(23)
# memory usage: 204.1+ KB

# %%
copia.head()
# Out:
#            date    home_team      away_team  home_score  away_score  \
# 94   2017-09-23  Aston Villa     Nottingham           2           1
# 95   2017-09-23       Bolton      Brentford           0           3
# 97   2017-09-23       Fulham  Middlesbrough           1           1
# 99   2017-09-23      Norwich   Bristol City           0           0
# 100  2017-09-23      Preston       Millwall           0           0
#
#     home_ball_possession away_ball_possession home_goal_attempts  \
# 94                   36%                  64%                 11
# 95                   43%                  57%                 10
# 97                   62%                  38%                 10
# 99                   49%                  51%                 15
# 100                  62%                  38%                 12
#
#     away_goal_attempts home_shots_on_goal away_shots_on_goal  \
# 94                  13                  4                  5
# 95                  22                  3                 10
# 97                  14                  4                  3
# 99                  10                  1                  3
# 100                 10                  2                  1
#
#     home_shots_off_goal away_shots_off_goal home_blocked_shots  \
# 94                    2                   4                  5
# 95                    5                   6                  2
# 97                    5                   8                  1
# 99                   10                   5                  4
# 100                   7                   5                  3
#
#     away_blocked_shots home_corner_kicks away_corner_kicks home_offsides  \
# 94                   4                 3                 4             3
# 95                   6                 5                 6             1
# 97                   3                 6                 3             2
# 99                   2                 3                 6             2
# 100                  4                 7                 7             1
#
#     away_offsides home_goalkeeper_saves away_goalkeeper_saves home_fouls  \
# 94              1                     4                     2         14
# 95              3                     7                     3         22
# 97              1                     2                     3         16
# 99              3                     3                     1         15
# 100             1                     1                     2         18
#
#     away_fouls home_yellow_cards away_yellow_cards  home_goals_diff  \
# 94           9                 1                 3                1
# 95          13                 2                 1               -3
# 97           8                 2                 1                0
# 99          19                 1                 1                0
# 100         16                 3                 1                0
#
#      away_goals_diff  home_5goals_diff  away_5goals_diff
# 94                -1              3.00             -2.00
# 95                 3             -9.00             -1.00
# 97                 0              0.00              1.00
# 99                 0              1.00              0.00
# 100                0              5.00             -2.00

# %%
final_df = copia.copy()

# %%
final_df['home_ball_possession'] = final_df['home_ball_possession'].apply(lambda x: int(x.split('%')[0]))
final_df['away_ball_possession'] = final_df['away_ball_possession'].apply(lambda x: int(x.split('%')[0]))

# %%
columns_list = ['home_goal_attempts', 'away_goal_attempts', 'home_shots_on_goal', 
                'away_shots_on_goal', 'home_shots_off_goal', 'away_shots_off_goal', 
                'home_blocked_shots', 'away_blocked_shots', 'home_corner_kicks', 
                'away_corner_kicks', 'home_offsides', 'away_offsides', 'home_goalkeeper_saves',
                'away_goalkeeper_saves', 'home_fouls', 'away_fouls','home_yellow_cards', 'away_yellow_cards']
for column in columns_list:
    final_df[column] = final_df[column].astype('int64')

# %%
final_df.reset_index(inplace=True, drop=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 29 columns):
# date                     871 non-null object
# home_team                871 non-null object
# away_team                871 non-null object
# home_score               871 non-null int64
# away_score               871 non-null int64
# home_ball_possession     871 non-null int64
# away_ball_possession     871 non-null int64
# home_goal_attempts       871 non-null int64
# away_goal_attempts       871 non-null int64
# home_shots_on_goal       871 non-null int64
# away_shots_on_goal       871 non-null int64
# home_shots_off_goal      871 non-null int64
# away_shots_off_goal      871 non-null int64
# home_blocked_shots       871 non-null int64
# away_blocked_shots       871 non-null int64
# home_corner_kicks        871 non-null int64
# away_corner_kicks        871 non-null int64
# home_offsides            871 non-null int64
# away_offsides            871 non-null int64
# home_goalkeeper_saves    871 non-null int64
# away_goalkeeper_saves    871 non-null int64
# home_fouls               871 non-null int64
# away_fouls               871 non-null int64
# home_yellow_cards        871 non-null int64
# away_yellow_cards        871 non-null int64
# home_goals_diff          871 non-null int64
# away_goals_diff          871 non-null int64
# home_5goals_diff         871 non-null float64
# away_5goals_diff         871 non-null float64
# dtypes: float64(2), int64(24), object(3)
# memory usage: 197.5+ KB

# %%
final_df.describe()
# Out:
#        home_score  away_score  home_ball_possession  away_ball_possession  \
# count      871.00      871.00                871.00                871.00
# mean         1.47        1.18                 51.51                 48.49
# std          1.18        1.07                 10.42                 10.42
# min          0.00        0.00                  8.00                 22.00
# 25%          1.00        0.00                 44.00                 41.00
# 50%          1.00        1.00                 52.00                 48.00
# 75%          2.00        2.00                 59.00                 56.00
# max          6.00        5.00                 78.00                 92.00
#
#        home_goal_attempts  away_goal_attempts  home_shots_on_goal  \
# count              871.00              871.00              871.00
# mean                13.70               11.30                4.45
# std                  4.74                4.31                2.35
# min                  2.00                1.00                0.00
# 25%                 11.00                8.00                3.00
# 50%                 13.00               11.00                4.00
# 75%                 16.00               14.00                6.00
# max                 36.00               28.00               15.00
#
#        away_shots_on_goal  home_shots_off_goal  away_shots_off_goal  \
# count              871.00               871.00               871.00
# mean                 3.74                 5.57                 4.54
# std                  2.14                 2.57                 2.38
# min                  0.00                 0.00                 0.00
# 25%                  2.00                 4.00                 3.00
# 50%                  3.00                 5.00                 4.00
# 75%                  5.00                 7.00                 6.00
# max                 12.00                16.00                15.00
#
#        home_blocked_shots  away_blocked_shots  home_corner_kicks  \
# count              871.00              871.00             871.00
# mean                 3.69                3.03               5.66
# std                  2.30                2.02               2.75
# min                  0.00                0.00               0.00
# 25%                  2.00                2.00               4.00
# 50%                  3.00                3.00               5.00
# 75%                  5.00                4.00               7.00
# max                 13.00               12.00              15.00
#
#        away_corner_kicks  home_offsides  away_offsides  home_goalkeeper_saves  \
# count             871.00         871.00         871.00                 871.00
# mean                4.72           1.61           1.72                   2.55
# std                 2.56           1.40           1.48                   1.75
# min                 0.00           0.00           0.00                   0.00
# 25%                 3.00           1.00           1.00                   1.00
# 50%                 4.00           1.00           1.00                   2.00
# 75%                 6.00           2.00           3.00                   4.00
# max                16.00           7.00           9.00                  11.00
#
#        away_goalkeeper_saves  home_fouls  away_fouls  home_yellow_cards  \
# count                 871.00      871.00      871.00             871.00
# mean                    2.98       11.76       12.41               1.64
# std                     1.98        3.53        3.66               1.22
# min                     0.00        2.00        1.00               0.00
# 25%                     2.00        9.00       10.00               1.00
# 50%                     3.00       12.00       12.00               2.00
# 75%                     4.00       14.00       15.00               2.00
# max                    12.00       23.00       25.00               6.00
#
#        away_yellow_cards  home_goals_diff  away_goals_diff  home_5goals_diff  \
# count             871.00           871.00           871.00            871.00
# mean                1.95             0.29            -0.29              1.46
# std                 1.33             1.60             1.60              4.21
# min                 0.00            -5.00            -6.00            -13.00
# 25%                 1.00            -1.00            -1.00             -1.00
# 50%                 2.00             0.00             0.00              1.00
# 75%                 3.00             1.00             1.00              4.00
# max                 7.00             6.00             5.00             15.00
#
#        away_5goals_diff
# count            871.00
# mean              -1.52
# std                4.09
# min              -13.00
# 25%               -4.00
# 50%               -2.00
# 75%                1.00
# max               10.00

# %%
final_df.head()
# Out:
#          date    home_team      away_team  home_score  away_score  \
# 0  2017-09-23  Aston Villa     Nottingham           2           1
# 1  2017-09-23       Bolton      Brentford           0           3
# 2  2017-09-23       Fulham  Middlesbrough           1           1
# 3  2017-09-23      Norwich   Bristol City           0           0
# 4  2017-09-23      Preston       Millwall           0           0
#
#    home_ball_possession  away_ball_possession  home_goal_attempts  \
# 0                    36                    64                  11
# 1                    43                    57                  10
# 2                    62                    38                  10
# 3                    49                    51                  15
# 4                    62                    38                  12
#
#    away_goal_attempts  home_shots_on_goal  away_shots_on_goal  \
# 0                  13                   4                   5
# 1                  22                   3                  10
# 2                  14                   4                   3
# 3                  10                   1                   3
# 4                  10                   2                   1
#
#    home_shots_off_goal  away_shots_off_goal  home_blocked_shots  \
# 0                    2                    4                   5
# 1                    5                    6                   2
# 2                    5                    8                   1
# 3                   10                    5                   4
# 4                    7                    5                   3
#
#    away_blocked_shots  home_corner_kicks  away_corner_kicks  home_offsides  \
# 0                   4                  3                  4              3
# 1                   6                  5                  6              1
# 2                   3                  6                  3              2
# 3                   2                  3                  6              2
# 4                   4                  7                  7              1
#
#    away_offsides  home_goalkeeper_saves  away_goalkeeper_saves  home_fouls  \
# 0              1                      4                      2          14
# 1              3                      7                      3          22
# 2              1                      2                      3          16
# 3              3                      3                      1          15
# 4              1                      1                      2          18
#
#    away_fouls  home_yellow_cards  away_yellow_cards  home_goals_diff  \
# 0           9                  1                  3                1
# 1          13                  2                  1               -3
# 2           8                  2                  1                0
# 3          19                  1                  1                0
# 4          16                  3                  1                0
#
#    away_goals_diff  home_5goals_diff  away_5goals_diff
# 0               -1              3.00             -2.00
# 1                3             -9.00             -1.00
# 2                0              0.00              1.00
# 3                0              1.00              0.00
# 4                0              5.00             -2.00

# %%
def result(df):
    if df['home_score'] > df['away_score']:
        return 'H'
    elif df['home_score'] < df['away_score']:
        return 'A'
    else:
        return 'D'

# %%
final_df['result'] = final_df.apply(result, axis=1)

# %%
final_df.head()
# Out:
#          date    home_team      away_team  home_score  away_score  \
# 0  2017-09-23  Aston Villa     Nottingham           2           1
# 1  2017-09-23       Bolton      Brentford           0           3
# 2  2017-09-23       Fulham  Middlesbrough           1           1
# 3  2017-09-23      Norwich   Bristol City           0           0
# 4  2017-09-23      Preston       Millwall           0           0
#
#    home_ball_possession  away_ball_possession  home_goal_attempts  \
# 0                    36                    64                  11
# 1                    43                    57                  10
# 2                    62                    38                  10
# 3                    49                    51                  15
# 4                    62                    38                  12
#
#    away_goal_attempts  home_shots_on_goal  away_shots_on_goal  \
# 0                  13                   4                   5
# 1                  22                   3                  10
# 2                  14                   4                   3
# 3                  10                   1                   3
# 4                  10                   2                   1
#
#    home_shots_off_goal  away_shots_off_goal  home_blocked_shots  \
# 0                    2                    4                   5
# 1                    5                    6                   2
# 2                    5                    8                   1
# 3                   10                    5                   4
# 4                    7                    5                   3
#
#    away_blocked_shots  home_corner_kicks  away_corner_kicks  home_offsides  \
# 0                   4                  3                  4              3
# 1                   6                  5                  6              1
# 2                   3                  6                  3              2
# 3                   2                  3                  6              2
# 4                   4                  7                  7              1
#
#    away_offsides  home_goalkeeper_saves  away_goalkeeper_saves  home_fouls  \
# 0              1                      4                      2          14
# 1              3                      7                      3          22
# 2              1                      2                      3          16
# 3              3                      3                      1          15
# 4              1                      1                      2          18
#
#    away_fouls  home_yellow_cards  away_yellow_cards  home_goals_diff  \
# 0           9                  1                  3                1
# 1          13                  2                  1               -3
# 2           8                  2                  1                0
# 3          19                  1                  1                0
# 4          16                  3                  1                0
#
#    away_goals_diff  home_5goals_diff  away_5goals_diff result
# 0               -1              3.00             -2.00      H
# 1                3             -9.00             -1.00      A
# 2                0              0.00              1.00      D
# 3                0              1.00              0.00      D
# 4                0              5.00             -2.00      D

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 30 columns):
# date                     871 non-null object
# home_team                871 non-null object
# away_team                871 non-null object
# home_score               871 non-null int64
# away_score               871 non-null int64
# home_ball_possession     871 non-null int64
# away_ball_possession     871 non-null int64
# home_goal_attempts       871 non-null int64
# away_goal_attempts       871 non-null int64
# home_shots_on_goal       871 non-null int64
# away_shots_on_goal       871 non-null int64
# home_shots_off_goal      871 non-null int64
# away_shots_off_goal      871 non-null int64
# home_blocked_shots       871 non-null int64
# away_blocked_shots       871 non-null int64
# home_corner_kicks        871 non-null int64
# away_corner_kicks        871 non-null int64
# home_offsides            871 non-null int64
# away_offsides            871 non-null int64
# home_goalkeeper_saves    871 non-null int64
# away_goalkeeper_saves    871 non-null int64
# home_fouls               871 non-null int64
# away_fouls               871 non-null int64
# home_yellow_cards        871 non-null int64
# away_yellow_cards        871 non-null int64
# home_goals_diff          871 non-null int64
# away_goals_diff          871 non-null int64
# home_5goals_diff         871 non-null float64
# away_5goals_diff         871 non-null float64
# result                   871 non-null object
# dtypes: float64(2), int64(24), object(4)
# memory usage: 204.3+ KB

# %%
final_df['home_goals_shots'] = final_df['home_score'] / final_df['home_shots_on_goal']
final_df['away_goals_shots'] = final_df['away_score'] / final_df['away_shots_on_goal']
final_df['home_goals_shots'].replace(np.inf, df['home_score'], inplace=True)
final_df['away_goals_shots'].replace(np.inf, df['away_score'], inplace=True)
final_df['home_goals_shots'].replace(np.nan, 0, inplace=True)
final_df['away_goals_shots'].replace(np.nan, 0, inplace=True)

# %%
final_df.head()
# Out:
#          date    home_team      away_team  home_score  away_score  \
# 0  2017-09-23  Aston Villa     Nottingham           2           1
# 1  2017-09-23       Bolton      Brentford           0           3
# 2  2017-09-23       Fulham  Middlesbrough           1           1
# 3  2017-09-23      Norwich   Bristol City           0           0
# 4  2017-09-23      Preston       Millwall           0           0
#
#    home_ball_possession  away_ball_possession  home_goal_attempts  \
# 0                    36                    64                  11
# 1                    43                    57                  10
# 2                    62                    38                  10
# 3                    49                    51                  15
# 4                    62                    38                  12
#
#    away_goal_attempts  home_shots_on_goal  away_shots_on_goal  \
# 0                  13                   4                   5
# 1                  22                   3                  10
# 2                  14                   4                   3
# 3                  10                   1                   3
# 4                  10                   2                   1
#
#    home_shots_off_goal  away_shots_off_goal  home_blocked_shots  \
# 0                    2                    4                   5
# 1                    5                    6                   2
# 2                    5                    8                   1
# 3                   10                    5                   4
# 4                    7                    5                   3
#
#    away_blocked_shots  home_corner_kicks  away_corner_kicks  home_offsides  \
# 0                   4                  3                  4              3
# 1                   6                  5                  6              1
# 2                   3                  6                  3              2
# 3                   2                  3                  6              2
# 4                   4                  7                  7              1
#
#    away_offsides  home_goalkeeper_saves  away_goalkeeper_saves  home_fouls  \
# 0              1                      4                      2          14
# 1              3                      7                      3          22
# 2              1                      2                      3          16
# 3              3                      3                      1          15
# 4              1                      1                      2          18
#
#    away_fouls  home_yellow_cards  away_yellow_cards  home_goals_diff  \
# 0           9                  1                  3                1
# 1          13                  2                  1               -3
# 2           8                  2                  1                0
# 3          19                  1                  1                0
# 4          16                  3                  1                0
#
#    away_goals_diff  home_5goals_diff  away_5goals_diff result  \
# 0               -1              3.00             -2.00      H
# 1                3             -9.00             -1.00      A
# 2                0              0.00              1.00      D
# 3                0              1.00              0.00      D
# 4                0              5.00             -2.00      D
#
#    home_goals_shots  away_goals_shots
# 0              0.50              0.20
# 1              0.00              0.30
# 2              0.25              0.33
# 3              0.00              0.00
# 4              0.00              0.00

# %% [markdown]
# ## Adicionando o Elo Score

# %%
from io import StringIO
list_df = []
for data in final_df.date.unique():
    elo_csv = requests.get(f"http://api.clubelo.com/{data}", allow_redirects=True)
    elo_csv = str(elo_csv.content,'utf-8')
    elo_csv = StringIO(elo_csv) 
    elo_df = pd.read_csv(elo_csv)
    list_df.append(elo_df)

# %%
elo_df_final = pd.concat(list_df)
elo_df_final.shape
# Out:
# (109027, 7)

# %%
elo_df_final.head()
# Out:
#   Rank         Club Country  Level      Elo        From          To
# 0    1  Real Madrid     ESP      1 2,062.51  2017-09-21  2017-09-23
# 1    2    Barcelona     ESP      1 2,046.01  2017-09-20  2017-09-23
# 2    3       Bayern     GER      1 1,967.59  2017-09-23  2017-09-26
# 3    4     Atletico     ESP      1 1,960.64  2017-09-21  2017-09-23
# 4    5     Juventus     ITA      1 1,956.76  2017-09-21  2017-09-23

# %%
elo_df_final.drop_duplicates(inplace=True)
elo_df_final.reset_index(drop=True)
# Out:
#        Rank               Club Country  Level      Elo        From          To
# 0         1        Real Madrid     ESP      1 2,062.51  2017-09-21  2017-09-23
# 1         2          Barcelona     ESP      1 2,046.01  2017-09-20  2017-09-23
# 2         3             Bayern     GER      1 1,967.59  2017-09-23  2017-09-26
# 3         4           Atletico     ESP      1 1,960.64  2017-09-21  2017-09-23
# 4         5           Juventus     ITA      1 1,956.76  2017-09-21  2017-09-23
# ...     ...                ...     ...    ...      ...         ...         ...
# 44273  None         Luch Minsk     BLR      1 1,152.11  2019-05-05  2019-05-11
# 44274  None  Vitosha Bistritsa     BUL      1 1,149.11  2019-05-03  2019-05-08
# 44275  None      Torpedo Minsk     BLR      1 1,133.82  2019-05-05  2019-05-12
# 44276  None             Dundee     SCO      1 1,123.46  2019-05-05  2019-05-11
# 44277  None             Vereya     BUL      1 1,026.56  2019-05-02  2019-07-01
#
# [44278 rows x 7 columns]

# %%
elo_df_eng = elo_df_final[elo_df_final['Country'] == 'ENG'].reset_index(drop=True)

# %%
elo_df_eng.head()
# Out:
#   Rank        Club Country  Level      Elo        From          To
# 0    6     Chelsea     ENG      1 1,915.90  2017-09-18  2017-09-23
# 1    7    Man City     ENG      1 1,906.20  2017-09-17  2017-09-23
# 2   10   Tottenham     ENG      1 1,892.49  2017-09-21  2017-09-23
# 3   11  Man United     ENG      1 1,888.46  2017-09-21  2017-09-23
# 4   14     Arsenal     ENG      1 1,845.44  2017-09-18  2017-09-23

# %%
copy_final_df = final_df.copy()
copy_final_df = copy_final_df.reset_index(drop=True)

# %%
copy_final_df.head()
# Out:
#          date    home_team      away_team  home_score  away_score  \
# 0  2017-09-23  Aston Villa     Nottingham           2           1
# 1  2017-09-23       Bolton      Brentford           0           3
# 2  2017-09-23       Fulham  Middlesbrough           1           1
# 3  2017-09-23      Norwich   Bristol City           0           0
# 4  2017-09-23      Preston       Millwall           0           0
#
#    home_ball_possession  away_ball_possession  home_goal_attempts  \
# 0                    36                    64                  11
# 1                    43                    57                  10
# 2                    62                    38                  10
# 3                    49                    51                  15
# 4                    62                    38                  12
#
#    away_goal_attempts  home_shots_on_goal  away_shots_on_goal  \
# 0                  13                   4                   5
# 1                  22                   3                  10
# 2                  14                   4                   3
# 3                  10                   1                   3
# 4                  10                   2                   1
#
#    home_shots_off_goal  away_shots_off_goal  home_blocked_shots  \
# 0                    2                    4                   5
# 1                    5                    6                   2
# 2                    5                    8                   1
# 3                   10                    5                   4
# 4                    7                    5                   3
#
#    away_blocked_shots  home_corner_kicks  away_corner_kicks  home_offsides  \
# 0                   4                  3                  4              3
# 1                   6                  5                  6              1
# 2                   3                  6                  3              2
# 3                   2                  3                  6              2
# 4                   4                  7                  7              1
#
#    away_offsides  home_goalkeeper_saves  away_goalkeeper_saves  home_fouls  \
# 0              1                      4                      2          14
# 1              3                      7                      3          22
# 2              1                      2                      3          16
# 3              3                      3                      1          15
# 4              1                      1                      2          18
#
#    away_fouls  home_yellow_cards  away_yellow_cards  home_goals_diff  \
# 0           9                  1                  3                1
# 1          13                  2                  1               -3
# 2           8                  2                  1                0
# 3          19                  1                  1                0
# 4          16                  3                  1                0
#
#    away_goals_diff  home_5goals_diff  away_5goals_diff result  \
# 0               -1              3.00             -2.00      H
# 1                3             -9.00             -1.00      A
# 2                0              0.00              1.00      D
# 3                0              1.00              0.00      D
# 4                0              5.00             -2.00      D
#
#    home_goals_shots  away_goals_shots
# 0              0.50              0.20
# 1              0.00              0.30
# 2              0.25              0.33
# 3              0.00              0.00
# 4              0.00              0.00

# %%
copy_final_df.home_team.unique()
# Out:
# array(['Aston Villa', 'Bolton', 'Fulham', 'Norwich', 'Preston', 'QPR',
#        'Sunderland', 'Sheffield Wed', 'Barnsley', 'Brentford',
#        'Bristol City', 'Burton', 'Cardiff', 'Hull City', 'Ipswich',
#        'Middlesbrough', 'Millwall', 'Nottingham', 'Birmingham',
#        'Sheffield Utd', 'Reading', 'Wolves', 'Leeds', 'Derby', 'Wigan',
#        'Stoke', 'West Brom', 'Blackburn', 'Swansea', 'Rotherham', 'Hull'],
#       dtype=object)

# %%
elo_df_eng.Club.unique()
# Out:
# array(['Chelsea', 'Man City', 'Tottenham', 'Man United', 'Arsenal',
#        'Liverpool', 'Everton', 'Leicester', 'Southampton', 'Stoke',
#        'West Ham', 'Burnley', 'Swansea', 'West Brom', 'Newcastle',
#        'Bournemouth', 'Watford', 'Crystal Palace', 'Brighton',
#        'Middlesbrough', 'Leeds', 'Sheffield Weds', 'Fulham', 'Hull',
#        'Sunderland', 'Huddersfield', 'Cardiff', 'Reading', 'Norwich',
#        'Preston', 'Wolves', 'Derby', 'Aston Villa', 'Brentford',
#        'Ipswich', 'Bristol City', 'QPR', 'Forest', 'Barnsley', 'Burton',
#        'Sheffield United', 'Millwall', 'Birmingham', 'Bolton',
#        'Rotherham', 'Wigan', 'Blackburn'], dtype=object)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
for team in list(copy_final_df.home_team.unique()):
    print(team)
    print(process.extract(team, elo_df_eng.Club.unique(), limit=2), end='')
    print('\n')
# Out:
# Aston Villa
# [('Aston Villa', 100), ('Stoke', 54)]
#
# Bolton
# [('Bolton', 100), ('Burton', 67)]
#
# Fulham
# [('Fulham', 100), ('Southampton', 60)]
#
# Norwich
# [('Norwich', 100), ('Ipswich', 57)]
#
# Preston
# [('Preston', 100), ('Forest', 62)]
#
# QPR
# [('QPR', 100), ('Preston', 60)]
#
# Sunderland
# [('Sunderland', 100), ('Huddersfield', 55)]
#
# Sheffield Wed
# [('Sheffield Weds', 96), ('Sheffield United', 83)]
#
# Barnsley
# [('Barnsley', 100), ('Burnley', 80)]
#
# Brentford
# [('Brentford', 100), ('Watford', 62)]
#
# Bristol City
# [('Bristol City', 100), ('Man City', 86)]
#
# Burton
# [('Burton', 100), ('Brighton', 71)]
#
# Cardiff
# [('Cardiff', 100), ('Watford', 43)]
#
# Hull City
# [('Hull', 90), ('Man City', 64)]
#
# Ipswich
# [('Ipswich', 100), ('Norwich', 57)]
#
# Middlesbrough
# [('Middlesbrough', 100), ('Leeds', 54)]
#
# Millwall
# [('Millwall', 100), ('Hull', 45)]
#
# Nottingham
# [('Tottenham', 74), ('Birmingham', 60)]
#
# Birmingham
# [('Birmingham', 100), ('Brighton', 56)]
#
# Sheffield Utd
# [('Sheffield United', 90), ('Sheffield Weds', 81)]
#
# Reading
# [('Reading', 100), ('Birmingham', 47)]
#
# Wolves
# [('Wolves', 100), ('Leeds', 55)]
#
# Leeds
# [('Leeds', 100), ('Leicester', 57)]
#
# Derby
# [('Derby', 100), ('Sunderland', 54)]
#
# Wigan
# [('Wigan', 100), ('Birmingham', 54)]
#
# Stoke
# [('Stoke', 100), ('Leicester', 60)]
#
# West Brom
# [('West Brom', 100), ('West Ham', 71)]
#
# Blackburn
# [('Blackburn', 100), ('Burton', 60)]
#
# Swansea
# [('Swansea', 100), ('Arsenal', 57)]
#
# Rotherham
# [('Rotherham', 100), ('Tottenham', 67)]
#
# Hull
# [('Hull', 100), ('Chelsea', 45)]

# %%
copy_final_df = copy_final_df[(copy_final_df['home_team'] != 'Nottingham') & (copy_final_df['away_team'] != 'Nottingham')]

# %%
for key, row in copy_final_df.iterrows():
    choices = list(elo_df_eng.Club.unique())
    home_team = process.extract(row['home_team'], choices, limit=2)[0][0]
    home_team_elo = elo_df_eng[(elo_df_eng['Club'] == home_team) & ((elo_df_eng['To'] == row['date']) | (elo_df_eng['From'] == row['date']))]['Elo']
    away_team = process.extract(row['away_team'], choices, limit=2)[0][0]
    away_team_elo = elo_df_eng[(elo_df_eng['Club'] == away_team) & ((elo_df_eng['To'] == row['date']) | (elo_df_eng['From'] == row['date']))]['Elo']
    if not home_team_elo.empty:
        copy_final_df.loc[key,'home_elo'] = home_team_elo.values[0]
    if not away_team_elo.empty:
        copy_final_df.loc[key,'away_elo'] = away_team_elo.values[0]

# %%
copy_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 798 entries, 1 to 870
# Data columns (total 34 columns):
# date                     798 non-null object
# home_team                798 non-null object
# away_team                798 non-null object
# home_score               798 non-null int64
# away_score               798 non-null int64
# home_ball_possession     798 non-null int64
# away_ball_possession     798 non-null int64
# home_goal_attempts       798 non-null int64
# away_goal_attempts       798 non-null int64
# home_shots_on_goal       798 non-null int64
# away_shots_on_goal       798 non-null int64
# home_shots_off_goal      798 non-null int64
# away_shots_off_goal      798 non-null int64
# home_blocked_shots       798 non-null int64
# away_blocked_shots       798 non-null int64
# home_corner_kicks        798 non-null int64
# away_corner_kicks        798 non-null int64
# home_offsides            798 non-null int64
# away_offsides            798 non-null int64
# home_goalkeeper_saves    798 non-null int64
# away_goalkeeper_saves    798 non-null int64
# home_fouls               798 non-null int64
# away_fouls               798 non-null int64
# home_yellow_cards        798 non-null int64
# away_yellow_cards        798 non-null int64
# home_goals_diff          798 non-null int64
# away_goals_diff          798 non-null int64
# home_5goals_diff         798 non-null float64
# away_5goals_diff         798 non-null float64
# result                   798 non-null object
# home_goals_shots         798 non-null float64
# away_goals_shots         798 non-null float64
# home_elo                 798 non-null float64
# away_elo                 798 non-null float64
# dtypes: float64(6), int64(24), object(4)
# memory usage: 258.2+ KB

# %%
copy_final_df.head()
# Out:
#          date home_team      away_team  home_score  away_score  \
# 1  2017-09-23    Bolton      Brentford           0           3
# 2  2017-09-23    Fulham  Middlesbrough           1           1
# 3  2017-09-23   Norwich   Bristol City           0           0
# 4  2017-09-23   Preston       Millwall           0           0
# 5  2017-09-23       QPR         Burton           0           0
#
#    home_ball_possession  away_ball_possession  home_goal_attempts  \
# 1                    43                    57                  10
# 2                    62                    38                  10
# 3                    49                    51                  15
# 4                    62                    38                  12
# 5                    63                    37                  13
#
#    away_goal_attempts  home_shots_on_goal  away_shots_on_goal  \
# 1                  22                   3                  10
# 2                  14                   4                   3
# 3                  10                   1                   3
# 4                  10                   2                   1
# 5                   5                   4                   1
#
#    home_shots_off_goal  away_shots_off_goal  home_blocked_shots  \
# 1                    5                    6                   2
# 2                    5                    8                   1
# 3                   10                    5                   4
# 4                    7                    5                   3
# 5                    3                    2                   6
#
#    away_blocked_shots  home_corner_kicks  away_corner_kicks  home_offsides  \
# 1                   6                  5                  6              1
# 2                   3                  6                  3              2
# 3                   2                  3                  6              2
# 4                   4                  7                  7              1
# 5                   2                  8                  6              1
#
#    away_offsides  home_goalkeeper_saves  away_goalkeeper_saves  home_fouls  \
# 1              3                      7                      3          22
# 2              1                      2                      3          16
# 3              3                      3                      1          15
# 4              1                      1                      2          18
# 5              2                      1                      4          17
#
#    away_fouls  home_yellow_cards  away_yellow_cards  home_goals_diff  \
# 1          13                  2                  1               -3
# 2           8                  2                  1                0
# 3          19                  1                  1                0
# 4          16                  3                  1                0
# 5          11                  0                  0                0
#
#    away_goals_diff  home_5goals_diff  away_5goals_diff result  \
# 1                3             -9.00             -1.00      A
# 2                0              0.00              1.00      D
# 3                0              1.00              0.00      D
# 4                0              5.00             -2.00      D
# 5                0              4.00            -10.00      D
#
#    home_goals_shots  away_goals_shots  home_elo  away_elo
# 1              0.00              0.30  1,324.42  1,464.26
# 2              0.25              0.33  1,543.04  1,563.94
# 3              0.00              0.00  1,509.35  1,463.22
# 4              0.00              0.00  1,502.02  1,380.96
# 5              0.00              0.00  1,447.36  1,405.12

# %%
copy_final_df.to_csv('class_data.csv', index=False, sep=';')
